# %%
import database
import stock_class
import datetime

# %%
mycursor, db = database.sql_connect(host='192.168.0.153', user = 'geri')
# Out:
# MySQL database password:Abcdef01.

# %%
db.is_connected()

# %%
database.price_query_sql(ticker_name = 'AAPL', mycursor=mycursor, db=db, end_date=datetime.date.today())
# Out:
#    ticker   high    low   open  close      volume adj_close      date_   id
# 0    AAPL  2.670  2.580  2.585  2.670   807234400     2.286 2006-01-03    4
# 1    AAPL  2.714  2.661  2.683  2.678   619603600     2.293 2006-01-04    5
# 2    AAPL  2.675  2.634  2.672  2.656   449422400     2.275 2006-01-05    6
# 3    AAPL  2.739  2.662  2.688  2.725   704457600     2.333 2006-01-06    7
# 4    AAPL  2.757  2.705  2.740  2.716   675040800     2.326 2006-01-09    8
# 5    AAPL  2.925  2.708  2.723  2.888  2279869200     2.473 2006-01-10    9
# 6    AAPL  2.757  2.705  2.740  2.716   675040800     2.336 2006-01-09   10
# 7    AAPL  2.925  2.708  2.723  2.888  2279869200     2.483 2006-01-10   11
# 8    AAPL  2.757  2.705  2.740  2.716   675040800     2.336 2006-01-09   14
# 9    AAPL  2.925  2.708  2.723  2.888  2279869200     2.483 2006-01-10   15
# 10   AAPL  2.757  2.705  2.740  2.716   675040800     2.336 2006-01-09   16
# ...
